# %%
import json
from collections import Counter
def proc(filename):
    with open(filename) as file:
        data=json.load(file)
    return data
data=proc("./out/crusoe.book")

def get_counter_from_dependency_list(dep_list):
    counter=Counter()
    for token in dep_list:
        term=token["w"]
        tokenGlobalIndex=token["i"]
        counter[term]+=1
    return counter
for character in data["characters"]:

    agentList=character["agent"]
    patientList=character["patient"]
    possList=character["poss"]
    modList=character["mod"]

    character_id=character["id"]
    count=character["count"]

    referential_gender_distribution=referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        print(character_id, count, max_proper_mention, referential_gender)

        print()
        printTop=10
        for k, v in get_counter_from_dependency_list(possList).most_common(printTop):
            print("\tposs\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(agentList).most_common(printTop):
            print("\tagent\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(patientList).most_common(printTop):
            print("\tpatient\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(modList).most_common(printTop):
            print("\tmod\t%s %s" % (v,k))
        print()
# Out:
# 106 284 God he/him/his
#
# 	poss	8 providence
# 	poss	4 sake
# 	poss	3 blessing
# 	poss	3 goodness
# 	poss	3 word
# 	poss	2 judgments
# 	poss	2 knowledge
# 	poss	2 appointment
# 	poss	2 presence
# 	poss	2 grace
#
# 	agent	4 told
# 	agent	3 knows
# 	agent	3 sent
# 	agent	3 made
# 	agent	3 appointed
# 	agent	3 thought
# 	agent	2 bless
# 	agent	2 have
# 	agent	2 given
# 	agent	2 speak
#
# 	patient	4 pleased
# 	patient	3 asked
# 	patient	2 please
# 	patient	2 understand
# 	patient	2 pray
# 	patient	1 say
# 	patient	1 thank
# 	patient	1 pleases
# 	patient	1 glorified
# 	patient	1 brought
#
# 	mod	1 pleased
# 	mod	1 able
# 	mod	1 act
# 	mod	1 holy
# 	mod	1 scholar
# 	mod	1 strong
# 	mod	1 great
# 	mod	1 stronger
# 	mod	1 delighted
#
# 150 191 Friday he/him/his
#
# 	poss	2 aim
# 	poss	2 father
# 	poss	2 pistol
# 	poss	1 nature
# 	poss	1 escape
# 	poss	1 fright
# 	poss	1 spirits
# 	poss	1 girdle
# 	poss	1 shoulder
# 	poss	1 side
#
# 	agent	9 did
# 	agent	6 came
# 	agent	5 says
# 	agent	5 killed
# 	agent	4 made
# 	agent	4 said
# 	agent	4 took
# 	agent	3 come
# 	agent	3 shot
# 	agent	3 saw
#
# 	patient	2 bid
# 	patient	2 killed
# 	patient	1 kill
# 	patient	1 told
# 	patient	1 asked
# 	patient	1 given
# 	patient	1 charged
# 	patient	1 bidding
# 	patient	1 asking
# 	patient	1 bade
#
# 	mod	2 able
# 	mod	1 cheerful
# 	mod	1 ready
# 	mod	1 frightened
#
# 161 155 the Spaniard he/him/his
#
# 	poss	13 father
# 	poss	3 countrymen
# 	poss	2 face
# 	poss	2 hands
# 	poss	2 head
# 	poss	2 opinion
# 	poss	1 girdle
# 	poss	1 might
# 	poss	1 chase
# 	poss	1 deliverance
#
# 	agent	6 went
# 	agent	5 said
# 	agent	4 speak
# 	agent	4 came
# 	agent	2 had
# 	agent	2 give
# 	agent	2 told
# 	agent	2 took
# 	agent	2 gave
# 	agent	2 given
#
# 	patient	2 delivered
# 	patient	2 ordered
# 	patient	1 wounded
# 	patient	1 plunged
# 	patient	1 tied
# 	patient	1 bound
# 	patient	1 helped
# 	patient	1 tell
# 	patient	1 revived
# 	patient	1 kissed
#
# 	mod	1 able
# 	mod	1 unbound
# 	mod	1 busy
# 	mod	1 fellow
# 	mod	1 handy
# 	mod	1 dexterous
#
# 117 67 Xury he/him/his
#
# 	poss	2 head
# 	poss	1 face
# 	poss	1 advice
# 	poss	1 blowing
# 	poss	1 skin
#
# 	agent	5 said
# 	agent	4 cut
# 	agent	3 says
# 	agent	2 go
# 	agent	2 have
# 	agent	1 stroke
# 	agent	1 make
# 	agent	1 spoke
# 	agent	1 cried
# 	agent	1 turned
#
# 	patient	2 frighted
# 	patient	1 throw
# 	patient	1 see
# 	patient	1 hear
# 	patient	1 asked
# 	patient	1 eat
# 	patient	1 sent
#
# 	mod	1 faithful
# 	mod	1 workman
# 	mod	1 counsellor
#
# 168 56 Tom Smith he/him/his
#
# 	poss	1 cave
# 	poss	1 service
# 	poss	1 habitation
# 	poss	1 opinion
# 	poss	1 thoughts
# 	poss	1 end
# 	poss	1 men
# 	poss	1 ambuscade
# 	poss	1 army
# 	poss	1 general
#
# 	agent	3 says
# 	agent	2 made
# 	agent	2 told
# 	agent	2 thought
# 	agent	2 answered
# 	agent	2 ordered
# 	agent	2 bid
# 	agent	2 drew
# 	agent	1 spoke
# 	agent	1 found
#
#
# 	mod	1 glad
# 	mod	1 afraid
# 	mod	1 willing
# 	mod	1 unwilling
# 	mod	1 men
#
# 156 32 Benamuckee he/him/his
#
# 	poss	2 enmity
# 	poss	2 nature
# 	poss	2 aversion
# 	poss	1 rebellion
# 	poss	1 snares
# 	poss	1 mind
# 	poss	1 origin
# 	poss	1 being
# 	poss	1 above
# 	poss	1 inclination
#
# 	agent	2 said
# 	agent	2 made
# 	agent	2 listened
# 	agent	1 setting
# 	agent	1 had
# 	agent	1 adapt
# 	agent	1 destroy
#
# 	patient	1 setting
# 	patient	1 telling
#
# 	mod	1 fire
#
# 120 29 Seignior Inglese he/him/his
#
# 	poss	1 foot
# 	poss	1 man
# 	poss	1 knife
# 	poss	1 bottle
# 	poss	1 pocket
# 	poss	1 debt
#
# 	agent	3 gave
# 	agent	2 said
# 	agent	2 saw
# 	agent	2 lifted
# 	agent	2 asked
# 	agent	1 says
# 	agent	1 rushed
# 	agent	1 showed
# 	agent	1 perceived
# 	agent	1 shouted
#
# 	patient	1 showed
# 	patient	1 saw
# 	patient	1 understood
#
#
# 166 29 Jack he/him/his
#
# 	poss	1 body
# 	poss	1 veins
# 	poss	1 mind
#
# 	agent	3 had
# 	agent	3 observed
# 	agent	2 saw
# 	agent	2 lodged
# 	agent	1 expected
# 	agent	1 wished
# 	agent	1 fell
# 	agent	1 secured
# 	agent	1 sat
# 	agent	1 came
#
# 	patient	1 put
# 	patient	1 gave
#
#
# 108 22 Robin Crusoe she/her
#
#
# 	agent	1 do
# 	agent	1 fool
# 	agent	1 call
# 	agent	1 ’re
# 	agent	1 came
#
# 	patient	1 frighted
# 	patient	1 fool
# 	patient	1 cry
#
#
# 109 22 Providence she/her
#
# 	poss	1 work
#
# 	agent	1 resolved
# 	agent	1 concurred
# 	agent	1 make
# 	agent	1 ruin
# 	agent	1 thought
# 	agent	1 suffered
# 	agent	1 called
# 	agent	1 seems
# 	agent	1 ensnared
# 	agent	1 fallen
#
# 	patient	1 tempt
#
# 	mod	1 merciful
#
# 132 20 Jesus Christ he/him/his
#
# 	poss	1 being
#
# 	agent	2 exalted
# 	agent	2 give
# 	agent	2 called
# 	agent	1 needs
# 	agent	1 dwelt
# 	agent	1 went
# 	agent	1 said
# 	agent	1 explain
#
# 	patient	1 sent
# 	patient	1 asked
#
#
# 83 17 St. Augustine he/him/his
#
# 	poss	1 account
# 	poss	1 friendship
# 	poss	1 family
# 	poss	1 dealings
# 	poss	1 industry
# 	poss	1 integrity
# 	poss	1 government
# 	poss	1 wife
# 	poss	1 daughters
#
# 	agent	2 had
# 	agent	2 sent
# 	agent	1 acknowledged
# 	agent	1 said
# 	agent	1 deliver
#
#
#
# 170 13 Atkins he/him/his
#
# 	poss	1 hands
# 	poss	1 arms
# 	poss	1 knees
#
# 	agent	1 cried
# 	agent	1 lay
# 	agent	1 trust
# 	agent	1 fell
# 	agent	1 begged
#
# 	patient	1 used
# 	patient	1 told
# 	patient	1 take
#
# 	mod	1 man
#
# 105 11 the Spaniards they/them/their
#
# 	poss	1 barbarities
#
# 	agent	1 destroyed
# 	agent	1 came
#
# 	patient	1 insulted
#
#
# 107 11 Heaven they/them/their
#
#
# 	agent	2 thought
# 	agent	1 oblige
# 	agent	1 convinced
# 	agent	1 directed
# 	agent	1 bestow
# 	agent	1 abandoned
# 	agent	1 sent
#
#
#
# 37 11 the Brazils they/them/their
#
# 	poss	1 ripe
# 	poss	1 rich
#
#
#
# 	mod	1 wholesome
# 	mod	1 agreeable
#
# 167 10 Animated he/him/his
#
# 	poss	2 hand
# 	poss	1 belt
# 	poss	1 comrades
#
# 	agent	1 took
# 	agent	1 cried
#
# 	patient	1 given
#
#
# 102 9 Robinson he/him/his
#
# 	poss	1 POSITION
#
# 	agent	1 said
# 	agent	1 asked
# 	agent	1 have
# 	agent	1 hail
#
#
#
# 155 9 the Caribbees they/them/their
#
# 	poss	1 plantations
# 	poss	1 enemies
# 	poss	1 plantation
#
# 	agent	1 came
# 	agent	1 invaded
# 	agent	1 fought
# 	agent	1 defeated
# 	agent	1 killed
# 	agent	1 famished
# 	agent	1 destroyed
#
# 	patient	1 invaded
#
#
# 129 7 Wretch he/him/his
#
#
# 	agent	1 dost
# 	agent	1 drowned
#
# 	patient	1 Dost
#
#
# 143 6 Satan he/him/his
#
# 	poss	1 foot
#
# 	agent	1 take
#
#
# 	mod	1 sure
# 	mod	1 simple
#
# 142 4 the Turks they/them/their
#
#
# 	agent	1 did
#
#
# 	mod	1 long
#
# 28 3 the Moors they/them/their
#
# 	poss	1 hunting
#
# 	agent	1 use
# 	agent	1 saw
# 	agent	1 go
#
#
#
# 130 3 the Brazilians they/them/their
#
# 	poss	1 tobacco
#
# 	agent	1 take
#
#
#
# 139 3 Father Abraham he/him/his
#
#
#
#
#
# 113 2 young Maresco he/him/his
#
#
#
# 	patient	1 took
#
#
# 118 2 Mahomet he/him/his
#
# 	poss	1 father
#
# 	agent	1 swear
#
#
#
# 121 2 Mr. Englishman he/him/his
#
#
# 	agent	1 carry
# 	agent	1 help
#
#
#
# 126 2 the Dutch he/him/his
#
#
#
#
#
# 137 2 the Indians they/them/their
#
#
#
#
#
# 141 2 Poll he/him/his
#
#
#
#
# 	mod	1 person
# 	mod	1 favourite
#
# 157 2 O he/him/his
#
#
#
#
#
# 176 2 Ha he/him/his
#
#
# 	agent	1 says
# 	agent	1 see
